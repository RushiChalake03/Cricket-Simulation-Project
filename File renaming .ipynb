# %% [markdown]
# ## 10-01-2022

# %% [markdown]
# #### Creating dataframe from multiple files

# %% [markdown]
# #### Sample Code :

# %%
import pandas as pd
import argparse
import os
import shutil

abs_dirname='C:\CricEleven\Folder1'
files1 = os.listdir(abs_dirname1)
print(files1)

for file in files1:
    read_f = pd.read_csv(os.path.join(abs_dirname, '{}'.format(file)))
    match_format = read_f.info__match_type[0]
    match_ID = int(read_f.info__match_type_number[0])
    print(match_format)
    print(match_ID)
    os.rename(os.path.join(abs_dirname, '{}'.format(file)),os.path.join(abs_dirname, '{}{}{}{}'.format(match_format,"_",match_ID,".csv")))
# Out:
# ['ODI3742.csv', 'ODI3744.csv', 'ODI3746.csv', 'T20558.csv', 'T20559.csv']
# ODI
# 3742
# ODI
# 3744
# ODI
# 3746
# T20
# 558
# T20
# 559

# %%
import pandas as pd
l = pd.read_csv("1007649.csv")
print(l.info__match_type[0])
# Out:
# ODI

# %%
import pandas as pd
import argparse
import os
import shutil

abs_dirname='E:\CRICELEVEN\Renamed Files by ID'
files = os.listdir(abs_dirname)
print(files)

for file in files:
    read_f = pd.read_csv(os.path.join(abs_dirname, '{}'.format(file)))
    match_format = read_f.info__match_type[0]
    match_ID = int(read_f.info__match_type_number[0])
    print(match_format)
    print(match_ID)
    os.rename(os.path.join(abs_dirname, '{}'.format(file)),os.path.join(abs_dirname, '{}{}{}{}'.format(match_format,"_",match_ID,".csv")))
# Out:
# ['1007649.csv', '1007651.csv', '1007653.csv', '1007655.csv', '1007657.csv', '1007659.csv', '1022353.csv', '1022361.csv', '1022367.csv', '1022373.csv', '1022375.csv', '1022593.csv', '1022595.csv', '1022599.csv', '1030217.csv', '1030219.csv', '1030221.csv', '1030223.csv', '1030225.csv', '1030227.csv', '1034811.csv', '1034813.csv', '1034815.csv', '1034819.csv', '1034821.csv', '1034823.csv', '1034825.csv', '1034827.csv', '1034829.csv', '1041615.csv', '1041617.csv', '1062573.csv', '1062574.csv', '1062575.csv', '1098206.csv', '1098207.csv', '1098208.csv', '1098209.csv', '1098210.csv', '1098211.csv', '1109603.csv', '1109604.csv', '1109605.csv', '1109606.csv', '1109607.csv', '1109608.csv', '1109610.csv', '1119496.csv', '1119497.csv', '1119498.csv', '1119499.csv', '1119500.csv', '1119501.csv', '1119502.csv', '1119543.csv', '1119544.csv', '1119545.csv', '1119546.csv', '1119547.csv', '1119548.csv', '1119549.csv', '1119550.csv', '1119552.csv', '1119553.csv', '1120090.csv', '1120091.csv', '112009
# ...
