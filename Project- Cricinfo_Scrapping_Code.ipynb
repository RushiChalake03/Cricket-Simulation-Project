# %%
import panda as pd

#For Overall Test Matches Data 
df = pd.read_html("https://stats.espncricinfo.com/ci/engine/stats/index.html?class=1;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=4;spanmin1=01+Apr+2015;spanval1=span;team=6;template=results;type=allround")[2]

df.to_csv('E:\Project CricEleven\Raw Data\Test Matches\All Players\Overall_Test.csv')

# %%
# For overall Test Batting records:
TestBat=pd.read_html("https://stats.espncricinfo.com/ci/engine/stats/index.html?batting_hand=1;batting_hand=2;class=1;filter=advanced;floodlit=1;floodlit=2;home_or_away=1;home_or_away=2;home_or_away=3;orderby=runs;result=1;result=2;result=3;result=4;size=150;spanmin1=01-03-2015;spanmin2=01+Jan+2015;spanval1=span;spanval2=span;team=6;template=results;tournament_type=2;tournament_type=3;tournament_type=5;type=batting")[2]

TestBat.to_csv('E:\Project CricEleven\Raw Data\Test Matches\All Players\Test_Batsmens.csv')

# %%
# For overall Test Bowling records:
TestBowl=pd.read_html("https://stats.espncricinfo.com/ci/engine/stats/index.html?class=1;filter=advanced;floodlit=1;floodlit=2;home_or_away=1;home_or_away=2;home_or_away=3;orderby=wickets;result=1;result=2;result=3;result=4;size=150;spanmin2=01+Jan+2015;spanval2=span;team=6;template=results;tournament_type=2;tournament_type=3;tournament_type=5;type=bowling")[2]

TestBowl.to_csv('E:\Project CricEleven\Raw Data\Test Matches\All Players\Test_Bowlers.csv')

# %%
# For overall Test Bowling records:
TestField=pd.read_html("https://stats.espncricinfo.com/ci/engine/stats/index.html?class=1;filter=advanced;floodlit=1;floodlit=2;home_or_away=1;home_or_away=2;home_or_away=3;orderby=dismissals;result=1;result=2;result=3;result=4;size=150;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;tournament_type=2;tournament_type=3;tournament_type=5;type=fielding")[2]

TestField.to_csv('E:\Project CricEleven\Raw Data\Test Matches\All Players\Test_Fielders.csv')

# %%
# For overall Test Matches records:
TestMatch=pd.read_html("https://stats.espncricinfo.com/ci/engine/team/6.html?class=1;filter=advanced;floodlit=1;floodlit=2;home_or_away=1;home_or_away=2;home_or_away=3;orderby=won;result=1;result=2;result=3;result=4;size=150;spanmin1=01+Jan+2015;spanval1=span;template=results;tournament_type=2;tournament_type=3;tournament_type=5;type=team;view=innings")[3]

TestMatch.to_csv('E:\Project CricEleven\Raw Data\Test Matches\All Players\Test_Matches.csv')

# %%
import pandas as pd

vk = pd.read_html("https://stats.espncricinfo.com/ci/engine/player/253802.html?class=1;filter=advanced;orderby=runs;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings")[3]
vk.to_csv('E:\Project CricEleven\Raw Data\Test Matches\Virat Kohli\VK_Test_Innings.csv')

# %%
Pujara = 'https://stats.espncricinfo.com/ci/engine/player/32540.html?class=1;filter=advanced;orderby=runs;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings'
Rahane = 'https://stats.espncricinfo.com/ci/engine/player/277916.html?class=1;filter=advanced;orderby=runs;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings'

# %%
import requests
from bs4 import BeautifulSoup

urls = 'https://www.geeksforgeeks.org/'
grab = requests.get(urls)
soup = BeautifulSoup(grab.text, 'html.parser')

# opening a file in write mode
f = open("test1.txt", "w")
# traverse paragraphs from soup
for link in soup.find_all("a"):
    data = link.get('href')
    f.write(data)
    f.write("\n")

f.close()
f
# Out:
# <_io.TextIOWrapper name='test1.txt' mode='w' encoding='cp1252'>

# %%
 
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re

req = Request("https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting")
html_page = urlopen(req)

soup = BeautifulSoup(html_page, "lxml")

links = []
for link in soup.findAll('a'):
    links.append(link.get('href'))

print(links)
# Out:
# ['/', '/live-cricket-score', '/live-cricket-score', 'https://www.espncricinfo.com/ci/engine/match/index.html?view=week', 'https://www.espncricinfo.com/ci/engine/series/index.html?view=month', 'https://www.espncricinfo.com/ci/engine/series/index.html?view=season', 'https://www.espncricinfo.com/ci/engine/match/index.html?view=calendar', 'https://www.espncricinfo.com/ci/engine/match/scores/desktop.html', 'https://www.espncricinfo.com/ci/content/match/fixtures_futures.html', '/series/new-zealand-in-india-2021-22-1278658', '/series/the-ashes-2021-22-1263452', '/series/west-indies-in-pakistan-2021-22-1287766', '/series/india-in-south-africa-2021-22-1277060', '/series/lanka-premier-league-2021-22-1291193', '/series/super-smash-2021-22-1289602', '/series/big-bash-league-2021-22-1269637', '/series/the-marsh-cup-2021-22-1270434', '/series/sheffield-shield-2021-22-1270433', '/series/quaid-e-azam-trophy-2021-22-1277307', '/series/national-cricket-league-2021-22-1283053', '/series/4-day-franchise
# ...

# %%
import pandas as pd

table = pd.read_html("https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting")[2]

table.to_csv("E:/Scrapping/Cric1.csv")

# %%
import requests
from bs4 import BeautifulSoup
 
urls = 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting'
grab = requests.get(urls)
soup = BeautifulSoup(grab.text, 'html.parser')
 
# opening a file in write mode
f = open("test1.txt", "w")
# traverse paragraphs from soup
for link in soup.find_all("a"):
    data = link.get('href')
    f.write(data)
    f.write("\n")
f.close()

# %%
import pandas as pd
dataLog = []
with open('test1.txt', 'rt') as f:
    data = f.readlines()
for line in data:
    if 'view=innings' in line:
        print(line)
        dataLog.append(line)
print(dataLog)
# Out:
# /ci/engine/stats/index.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings
#
# /ci/engine/player/253802.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings
#
# /ci/engine/player/34102.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings
#
# /ci/engine/player/28235.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings
#
# ...

# %%
pwd
# Out:
# 'C:\\Users\\dell'

# %%
lines = dataLog
with open('links123.txt', 'w') as f:
    for line in lines:
        
        
        f.write('https://stats.espncricinfo.com' + line )
        #print(line)
        #line.replace(" ","")
        #f.write('\n')
#f.close

# %%
import pandas as pd
import re
file1 = open('links123.txt', 'r')
Lines = file1.readlines()
Links = Lines[1:]
Directory= 'E:\Project CricEleven\Raw Data\Test Matches\All Players\Player'

for line in Links:
    url= line
    df = pd.read_html(url)[3]
    PlayerID =re.search('player/(.+?).html', url).group(1)
    File_Ext = ".csv"
    title = PlayerID + File_Ext
    df.to_csv( Directory + title)
PlayerID
# Out:
# '714451'

# %%
import pandas as pd
import re
df = pd.read_html("https://stats.espncricinfo.com/ci/engine/player/537124.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings")[3]
Directory= 'E:\Project CricEleven\Raw Data\Test Matches\All Players\Player'

Pla_ID = 
File_Ext = ".csv"4
title = Pla_ID + File_Ext
print(title)
#df.to_csv('E:\Project CricEleven\Raw Data\Test Matches\All Players\Overall_Test.csv')
df.to_csv( Directory + title)
df
# Out:
# 4578.csv
#   Runs  Mins  BF  4s  6s      SR  Pos Dismissal  Inns  Unnamed: 9  \
# 0    8     6   7   1   0  114.28    6    bowled     1         NaN
# 1    5     9   6   1   0   83.33    5    caught     2         NaN
# 2   0*     2   0   0   0       -    6   not out     2         NaN
#
#     Opposition     Ground   Start Date Unnamed: 13
# 0  v Australia  Melbourne  17 Jan 2016  ODI # 3725
# 1  v Australia   Canberra  20 Jan 2016  ODI # 3726
# 2  v Australia     Sydney  23 Jan 2016  ODI # 3727

# %%
l="vgghufgf123456vfjhbvfhb"
PlayerID = str(l[8:15])
File_Ext = ".csv"
title = PlayerID + File_Ext
    #df.to_csv( Directory + title)
print(PlayerID)
# Out:
# 123456v

# %%
import re

string = "https://stats.espncricinfo.com/ci/engine/player/625383.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;result=1;result=2;result=3;result=5;spanmin1=01+Jan+2015;spanval1=span;team=6;template=results;type=batting;view=innings"

found = re.search('player/(.+?).html', string).group(1)
print(found)
# Out:
# 625383

# %% [markdown]
# # BALL BY BALL DATA

# %% [markdown]
# ## Converting JSON file into CSV formats

# %%
import json
 
with open('64083.json') as f:
    superHeroSquad = json.load(f)
type(superHeroSquad)
# Output: dict
superHeroSquad.keys()
# Output: dict_keys(['squadName', 'homeTown', 'formed', 'secretBase', 'active', 'members'])
pd.json_normalize(superHeroSquad, record_path = ['meta'], meta = ["data_version", "created", "revision"])
#s=match_commentary['meta'].apply(pd.Series)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-e8aa17cbbbdf> in <module>
#       7 superHeroSquad.keys()
#       8 # Output: dict_keys(['squadName', 'homeTown', 'formed', 'secretBase', 'active', 'members'])
# ----> 9 pd.json_normalize(superHeroSquad, record_path = ['meta'], meta = ["data_version", "created", "revision"])
#      10 #s=match_commentary['meta'].apply(pd.Series)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     334                 records.extend(recs)
#     335
# --> 336     _recursive_extract(data, record_path, {}, level=0)
#     337
#     338     result = DataFrame(records)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     307         else:
# ...

# %%
import pandas as pd
df = pd.read_json('64083.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-8e9e6b69b05e> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_json('64083.json')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
import pandas as pd
import os
import json
import csv

jsonfile=pd.read_json('64083.json')
def create_list_from_json(jsonfile):

    with open(jsonfile) as f:
        data = json.load(f)

    data_list = []  # create an empty list

    # append the items to the list in the same order.
    data_list.append(data['meta'][])
    data_list.append(data['_modelType'])
    data_list.append(data['creator']['_id'])
    data_list.append(data['creator']['name'])
    data_list.append(data['dataset']['_accessLevel'])
    data_list.append(data['dataset']['_id'])
    data_list.append(data['dataset']['description'])
    data_list.append(data['dataset']['name'])
    data_list.append(data['meta']['acquisition']['image_type']) #here we are reading in the nested JSON
    data_list.append(data['meta']['acquisition']['pixelsX'])
    data_list.append(data['meta']['acquisition']['pixelsY'])
    data_list.append(data['meta']['clinical']['age_approx'])
    data_list.append(data['meta']['clinical']['benign_malignant'])
    data_list.append(data['meta']['clinical']['diagnosis'])
    data_list.append(data['meta']['clinical']['diagnosis_confirm_type'])
    data_list.append(data['meta']['clinical']['melanocytic'])
    data_list.append(data['meta']['clinical']['sex'])
    data_list.append(data['meta']['unstructured']['diagnosis'])
    # In few json files, the race was not there so using KeyError exception to add '' at the place
    try:
        data_list.append(data['meta']['unstructured']['race'])
    except KeyError:
        data_list.append("")  # will add an empty string in case race is not there.
    data_list.append(data['name'])

    return data_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9bb8402dc404> in <module>
#      16 df.to_csv('done.csv', encoding='utf-8', index=False)
#      17
# ---> 18 done.close('done.csv')
#
# NameError: name 'done' is not defined

# %%
import os
import json
import csv
